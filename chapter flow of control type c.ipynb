# %%
h = int(input("Enter hour between 1- 12:"))
a = int(input("How many hours ahead..:"))
diff = (h+a)-12
print("Time at that time:",diff,"0\'clock")
# Out:
# Enter hour between 1- 12:9
# How many hours ahead..:5
# Time at that time: 2 0'clock

# %%
n = int(input("enter an integer:"))
if n>0:
    for a in range(1,n+n):
        print(a/(n/2))
    else:
        print("Now quiting")
# Out:
# enter an integer:-1

# %%
n = int(input("enter an integer:"))
if n>0:
    for a in range(1,n+n):
        print(a/(n/2))
             
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
    
else:
        print("Now quiting")
# Out:
# enter an integer:-1
# Now quiting
