# %%
#identifiers 
#no keywords,
while = 5
print("End")
# Out:
#   Cell In[3], line 3
#     while = 5
#           ^
# SyntaxError: invalid syntax

# %%
#should not starts with digit
name = 'baba'
print(name)
# Out:
# baba

# %%
#should not starts with digit
1name = 'baba'
print(name)
# Out:
#   Cell In[6], line 2
#     1name = 'baba'
#     ^
# SyntaxError: invalid decimal literal

# %%
#can have a digit but should not be in a first charater
nam5e1 = 'baba'
print(name)
# Out:
# baba

# %%
#should not be have any special charaters other than _
first name = 'baba'
print(name)
# Out:
#   Cell In[10], line 2
#     first name = 'baba'
#           ^
# SyntaxError: invalid syntax

# %%
#should not be have any special charaters other than _
first_name = 'baba'
print(name)
# Out:
# baba

# %%
#should not be have any special charaters other than _
first@name = 'baba'
print(name)
# Out:
#   Cell In[12], line 2
#     first@name = 'baba'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
dudedont=5

# %%
print(type(dudedont))
# Out:
# <class 'int'>

# %%
x='dudedont'*1000
print(x)
# Out:
# ...

# %%
#no maximum limit for a variable length
...100

# %%
...1000

# %%
print(type(...
))
# Out:
# <class 'int'>

# %%
print(...
)
# Out:
# 1000

# %%
print(id(...
))
# Out:
# 1437475838192

# %%
import keyword as k
print(k.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#should not be have any special charaters other than _
first_name = 'baba'
print(first_name)
# Out:
# baba

# %%
#should not be have any special charaters other than _
#first_name = 'baba'
print(First_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 #should not be have any special charaters other than _
#       2 #first_name = 'baba'
# ----> 3 print(First_name)
#
# NameError: name 'First_name' is not defined

# %%
#literal - fixed constant values

# %% [markdown]
# shop= 'pencil'
# shop= 'Buy 10 pencils'
# type(shop)
# <class 'str'>
# type('pen')
# <class 'str'>
# type("pen")
# <class 'str'>
# type("""pen""")
# <class 'str'>
# type(''' pen''')
# <class 'str'>
# shop= 'Buy 10 pencils @ raju's shop '
# SyntaxError: unterminated string literal (detected at line 1)
# shop= 'Buy 10 pencils @ raju"s shop '
# shop
# 'Buy 10 pencils @ raju"s shop '
# shop= "Buy 10 pencils @ raju's shop "
# shop
# "Buy 10 pencils @ raju's shop "
# print(shop)
# Buy 10 pencils @ raju's shop
# shop= 'Buy 10 pencils @ raju\"s shop '
# shop
# 'Buy 10 pencils @ raju"s shop '
# shop= "Buy 10 pencils @ raju\\'s shop "
# shop
# "Buy 10 pencils @ raju\\'s shop "
# shop= 'Buy 10 pencils @ raju\'s shop '
# shop
# "Buy 10 pencils @ raju's shop "

# %%
#numeric literal -constant [int,float,complex]
price = 100
type(price)
<class 'int'>
price = 100.70
type(price)
<class 'float'>
price = 100+5j
type(price)
<class 'complex'>

# %%
x = 11
oct(x)
'0o13'
y = 0O13 #octal to decimal
y
11
z = 0o13
z
11
x = 11
hex(x)
'0xb'
y = 0Xb #hexadecimal
y
11
z = 0xb
z
11

# %%
x = .5
x = 11
oct(x)
'0o13'
y = 0O13 #octal to decimal
y
11
z = 0o13
z
11
x = 11
hex(x)
'0xb'
y = 0Xb
y
11
z = 0xb
z
11
# Out:
# 0.5 <class 'float'> 2774522852464

# %%
y = 11111111111111111111111111111111111111.5
print(y,type(y),id(y))
# Out:
# 1.111111111111111e+37 <class 'float'> 2774522852400

# %% [raw]
# y = 11111111111111111.5
# print(y,type(y),id(y))

# %%
if a = 6:
    print("Hey !!! I'm Done!!!!")%%!

# %%
#floating point

a = -10.5
b = 10.5 
c = .56
print(a, type(a),id(a))
print(b,type(b),id(b))
print(c,type(c),id(c))
# Out:
# -10.5 <class 'float'> 2239949566576
# 10.5 <class 'float'> 2239951840784
# 0.56 <class 'float'> 2239949567344

# %%
for i in range(0,255):
    print(i, id(i))
# Out:
# 0 140714079064840
# 1 140714079064872
# 2 140714079064904
# 3 140714079064936
# 4 140714079064968
# 5 140714079065000
# 6 140714079065032
# 7 140714079065064
# 8 140714079065096
# 9 140714079065128
# 10 140714079065160
# 11 140714079065192
# 12 140714079065224
# 13 140714079065256
# 14 140714079065288
# 15 140714079065320
# 16 140714079065352
# 17 140714079065384
# 18 140714079065416
# 19 140714079065448
# 20 140714079065480
# 21 140714079065512
# 22 140714079065544
# 23 140714079065576
# 24 140714079065608
# 25 140714079065640
# 26 140714079065672
# 27 140714079065704
# 28 140714079065736
# 29 140714079065768
# 30 140714079065800
# 31 140714079065832
# 32 140714079065864
# 33 140714079065896
# 34 140714079065928
# 35 140714079065960
# 36 140714079065992
# 37 140714079066024
# 38 140714079066056
# 39 140714079066088
# 40 140714079066120
# 41 140714079066152
# 42 140714079066184
# 43 140714079066216
# 44 140714079066248
# 45 140714079066280
# 46 140714079066312
# 47 140714079066344
# ...

# %%
d = 0.58 * 10 ** 1
print(d,type(d))
# Out:
# 5.8 <class 'float'>

# %%
e = 0.58E01
print(e, id(e),type(e))
# Out:
# 5.8 2239919650704 <class 'float'>

# %%
d = 0.58 * 10 ** 11
print(d,type(d))
e = 0.58E11
print(e, id(e),type(e))
# Out:
# 57999999999.99999 <class 'float'>
# 58000000000.0 2239949567280 <class 'float'>

# %%
f = 0.56E
e = 0.58E01
print(e, id(e),type(e))
# Out:
#   Cell In[7], line 1
#     f = 0.56E
#            ^
# SyntaxError: invalid decimal literal

# %%
g = .5E1.5
# Out:
#   Cell In[11], line 1
#     g = .5E1.5
#             ^
# SyntaxError: invalid syntax

# %%
sal = 50000
type(sal)
# Out:
# int

# %%
#complex
en = 5 + 6j
print(en, type(en),en.real, en.imag)
# Out:
# (5+6j) <class 'complex'> 5.0 6.0

# %%
#complex
en = 6j
print(en, type(en),en.real, en.imag)
# Out:
# 6j <class 'complex'> 0.0 6.0

# %%
#complex
en = 5
print(en, type(en),en.real, en.imag)
# Out:
# 5 <class 'int'> 5 0

# %%
#complex
en = 5.88 - 5J
print(en, type(en),en.real, en.imag)
# Out:
# (5.88-5j) <class 'complex'> 5.88 -5.0

# %%
power = True
print(power,type(power),id(power),":",type(1),id(1))
# Out:
# True <class 'bool'> 140714077596192 : <class 'int'> 140714079064872

# %%
p = True
print(id(int(p)))
# Out:
# 140714079064872

# %%
power = False
print(power,type(power),id(power),":",type(0),id(0))
# Out:
# False <class 'bool'> 140714077596224 : <class 'int'> 140714079064840

# %%
#Special Literal
language = None
print(language,type(language),id(language))
# Out:
# None <class 'NoneType'> 140714077678320

# %%
s= "Python \n is \n a \nprogramming language"

# %%
print(s)
# Out:
# Python
#  is
#  a
# programming language

# %%
s= "Python is a programming language\
3.11.0"

# %%
s
# Out:
# 'Python is a programming language3.11.0'

# %%
s= """Python is a programming language
its a object oriented language
its a high level programming language
# Out:
#   Cell In[30], line 1
#     s= """Python is a programming language
#        ^
# SyntaxError: incomplete input

# %%
#multi line
s = """Python is a programming language
its a object oriented language
its a high level # programming language""" #string literal

# %%
s
# Out:
# 'Python is a programming language\nits a object oriented language\nits a high level programming language'

# %%
print(s)
# Out:
# Python is a programming language
# its a object oriented language
# its a high level programming language

# %%
book = 60
print(type(book))
print(id(book))
print(book)
book = 70
print(type(book))
print(id(book))
print(book)
# Out:
# <class 'int'>
# 140725550160520
# 60
# <class 'int'>
# 140725550160840
# 70

# %%
for i in range(60,71):
    print(id(i))
# Out:
# 140725550160520
# 140725550160552
# 140725550160584
# 140725550160616
# 140725550160648
# 140725550160680
# 140725550160712
# 140725550160744
# 140725550160776
# 140725550160808
# 140725550160840

# %%
x = "abcdegdsaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaasgggg\
gfffffffff"
print(x)
# Out:
# abcdegdsaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaasgggggfffffffff

# %%
x = """abcdegd
gfffffffff"""
print(x)
# Out:
# abcdegd
# gfffffffff

# %%
x ="hello"
print(x)
x[1] = 'f'
# Out:
# hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 x ="hello"
#       2 print(x)
# ----> 3 x[1] = 'f'
#
# TypeError: 'str' object does not support item assignment
